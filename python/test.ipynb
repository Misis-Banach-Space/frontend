# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/nadezhda-siren/Hope/kokos_hack/frontend/python/test.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/home/nadezhda-siren/Hope/kokos_hack/frontend/python/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import requests
#       <a href='vscode-notebook-cell:/home/nadezhda-siren/Hope/kokos_hack/frontend/python/test.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/home/nadezhda-siren/Hope/kokos_hack/frontend/python/test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'requests'

# %%
LINK = 'https://misis.ru'

# %%
import re
DOMAIN_NAME = re.findall(r'([\w.-]+\.[\w.-]+)', LINK)[0]

# %%
DOMAIN_NAME
# Out:
# 'misis.ru'

# %%
URL = f'https://be1.ru/stat/{DOMAIN_NAME}'
req = requests.get(URL)
soup = BeautifulSoup(req.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head>
# <title>Анализ сайта онлайн | SEO-аудит бесплатно - Be1.ru</title>
# <meta content="Комплексный бесплатный анализ сайтов по ряду важных при продвижении показателей. Будет полезен как SEO-оптимизаторам, так и владельцам сайтов." name="description"/>
# <meta content="" name="keywords"/>
# <meta content="Анализ сайта онлайн | SEO-аудит бесплатно - Be1.ru" property="og:title"/>
# <meta content="Комплексный бесплатный анализ сайтов по ряду важных при продвижении показателей. Будет полезен как SEO-оптимизаторам, так и владельцам сайтов." property="og:description"/>
# <meta content="noyaca, noodp" name="robots"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="https://be1.ru/template/be1/images/main_fon.jpg" property="og:image"/>
# <link href="https://be1.ru/template/be1/images/main_fon.jpg" rel="image_src"/>
# <meta content="https://be1.ru/stat/misis.ru" property="og:url"/>
# <meta content="ru_RU" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Be1.ru" property="og:site_name"/>
# <link href="https://be1.ru/stat/misis.ru/" rel="canonical"/>
# <meta charset="utf-8"/>
# <meta http-equiv="X-UA-Compatible">
# <!--meta http-equiv="Cache-Control" content="max-age=60, public, must-revalidate, proxy-revalidate" /-->
# <meta content="width=device-width" name="viewport"/>
# <link href="https://chrome.google.com/webstore/detail/hgoppfmeamohhpdlgmbondkfcijhklbo" rel="chrome-webstore-item"/>
# <link href="/favicon.ico" rel="shortcut icon">
# <link href="/template/be1/vendor/font-awesome-4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/template/be1/fonts/be1/css/fontello.css?v=24" rel="stylesheet"/>
# <link href="/template/be1/vendor/jquery-ui/1.12.1.custom/jquery-ui.min.css" rel="stylesheet"/>
# <!-- Latest compiled and minified CSS -->
# <link href="/template/be1/vendor/bootstrap-3.3.7/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/template/be1/css/style.css?v=78" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Oxygen:300,400|Roboto:300" rel="stylesheet">
# <link href="https://be1.ru/template/be1/vendor/silviomoreto-bootstrap-select/css/bootstrap-select.min.css" rel="stylesheet">
# <link href="https://be1.ru/template/be1/css/tools/analiz_saita_view.css?v=28" rel="stylesheet">
# <script src="/template/be1/vendor/jquery/jquery-2.2.4.min.js"></script>
# <script async="" data-ad-client="ca-pub-6303903289357089" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- Yandex.RTB -->
# <script>window.yaContextCb=window.yaContextCb||[]</script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# </link></link></link></link></meta></head>
# <body>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter40221704 = new Ya.Metrika({
#                     id:40221704,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     trackHash:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://cdn.jsdelivr.net/npm/yandex-metrica-watch/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/40221704" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <div class="section_header header2">
# <div class="container">
# <a href="/">
# <div class="logo2">
# <!--<div class="xmas_wreath"></div>
# 			<div class="xmas_head"></div>-->
# <!--div class="halloween_head"></div-->
# </div>
# </a>
# <div class="menu2">
# <ul class="menu">
# <li><a href="/stat/">Анализ сайта</a></li>
# <li><a href="/antiplagiat-online/">Антиплагиат</a></li>
# <li><a href="/audit/">Аудит сайта</a></li>
# <li><a href="/services/prodvizhenie/analyticheskie-sistemy/">Рейтинг сервисов</a></li>
# <li><a href="/bookmarklet/">Букмарклеты</a></li>
# <li><a href="/api/">API</a></li>
# <li><a class="logout" data-target="#login_form" data-toggle="modal" href="#">Авторизация <span aria-hidden="true" class="glyphicon glyphicon-triangle-right font9"></span></a></li>
# </ul>
# </div>
# <div class="open_mobile_menu">
# <div class="bar1"></div>
# <div class="bar2"></div>
# <div class="bar3"></div>
# </div>
# </div>
# </div><div>
# <div>
# <div id="left_panel">
# <div class="news-flex">
# <div class="news-flex-content">
# <div class="row">
# <div class="close_btn"><a>X</a></div>
# <div class="col-md-12">
# <ul class="nav nav-tabs" role="tablist">
# <li class="active" role="presentation"><a aria-controls="news_be1" class="nonedecoration" data-toggle="tab" href="#news_be1" role="tab">Новости Be1.ru</a></li>
# <li class="hidden" role="presentation"><a aria-controls="news_seo" class="nonedecoration" data-toggle="tab" href="#news_seo" role="tab">Новости SEO</a>
# </li></ul>
# <div class="tab-content news_tab-content">
# <div class="tab-pane active" id="news_be1" role="tabpanel">
# <div class="row">
# <div class="col-md-12">
# <div class="news_list"></div>
# </div>
# </div>
# </div>
# <div class="tab-pane" id="news_seo" role="tabpanel">
# <div class="row">
# <div class="col-md-12">
# <div class="news_list"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="news-flex-other">
# <div class="panel panel-default margin_bottom0">
# <div class="panel-body" id="subscript_panel1">
#                         Подписаться на новости Be1.ru
#                         <div class="input-group margin_top5">
# <input class="form-control" id="subscriptEmail1" placeholder="Ваш email" type="email" value=""/>
# <span class="input-group-btn">
# <button class="btn btn-primary bt_subscript" data-button="submit" data-section="1">Подписаться</button>
# </span>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-6 padding_right2 margin_top10">
# <div class="panel panel-default">
# <div class="panel-body text-center">
# <div class="row">
# <div class="col-md-3">
# <img alt="vk_logo" src="/template/be1/images/icon-vkontakte.png"/>
# </div>
# <div class="col-md-9 padding_left0">
# <a href="https://vk.com/be1_ru" target="_blank">Be1 Вконтакте</a><br/>
# <div class="font12 margin_top5">1251 подписчиков</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-6 padding_left2 margin_top10">
# <div class="panel panel-default">
# <div class="panel-body text-center">
# <div class="row">
# <div class="col-md-3">
# <img alt="fb_logo" src="/template/be1/images/icon-facebook.png"/>
# </div>
# <div class="col-md-9 padding_left0">
# <a href="https://www.facebook.com/Be1ru-406095183066973" target="_blank">Be1 Facebook</a><br/>
# <div class="font12 margin_top5">1567 подписчиков</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="slide hide-on-mobile">
# <div class="btn-slide">
# <span class="fa-stack fa-sm">
# <i class="fa fa-circle-thin fa-stack-1x"></i>
# <i class="fa fa-angle-down fa-stack-1x" id="news_arrow_stack"></i>
# </span>
#             Новости
#         </div>
# </div>
# </div>
# <div id="shadow"></div>
# <script>
#     var last_news_id = 391;
#     var status_open = false;
# </script>
# <script src="https://www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script type="text/javascript">
#     google.charts.load('current', {
#         'packages': ['corechart', 'line', 'geochart'],
#         'language': 'ru',
#         'mapsApiKey': 'AIzaSyBNGW1nRclh5B79L8YP8ffwfyHhIyoiGXE', // for geochart
#     });
# </script>
# <div class="progress height5 margin_bottom5">
# <div aria-valuemax="100" aria-valuemin="0" aria-valuenow="45" class="progress-bar progress-bar-striped background_orang active" id="progressbar" role="progressbar" style="width: 0%">
# <!--45%-->
# </div>
# </div>
# <div class="container">
# <div class="row margin_top20 margin_bottom20">
# <div class="col-xs-3 col-md-1">
# <div class="ico_analiz_saita"></div>
# </div>
# <div class="col-xs-9 col-md-4 col-md-push-7 text-right">
# <div class="report-date">
#                 Отчет за: 28 сентября 2023, 09:03                <a href="/stat/refresh?url=misis.ru"><i class="fa fa-refresh"></i></a>
# </div>
# <a class="download-as-pdf mobile-app-hidden" href="#" onclick="downloadPdf(); return false;"><img height="18" src="/template/be1/images/pdf.svg"/>Скачать в PDF формате</a>
# </div>
# <div class="col-xs-12 col-md-7 col-md-pull-4">
# <form action="/stat/" class="margin_top7" id="tool-form">
# <div class="input-group input-group-lg">
# <input class="form-control" id="url" name="url" placeholder="Введите адрес сайта" type="text" value="misis.ru"/>
# <span class="input-group-btn">
# <button class="btn btn2">Анализировать</button>
# </span>
# </div>
# <div class="alert alert-danger fade in alert-dismissable hidden"></div>
# </form>
# </div>
# </div>
# <!--
#     <div class="row margin_top20 margin_bottom20">
#         <div class="col-md-1 col-sm-2 hidden-xs block_ico_analiz_saita">
#             <div class="ico_analiz_saita"></div>
#         </div>
#
#         <div class="col-md-7 col-sm-10 col-xs-12">
#             <h1>
#                 Анализ сайта
#                 <a href="http://misis.ru" target="_blank">misis.ru</a>&nbsp
#                 <a href="/stat/refresh" class="refresh hidden-xs hidden-sm" title="Перепроверить сайт">Перепроверить</a>
#                 <a href="/stat/refresh" class="nonedecoration hidden-md hidden-lg" title="Перепроверить сайт"><span class="glyphicon glyphicon-refresh font13 col_orang2" aria-hidden="true"></span></a>
#             </h1>
#             <h4>Комплексный анализ сайта поможет узнать его основные характеристики.</h4>
#         </div>
#
#         <div class="col-xs-12 col-md-4 padding_top15" id="tool-form-container">
#             <form action="/stat/" id="tool-form">
#                 <div class="input-group input-group-lg">
#                     <input type="text" name="url" id="url" class="form-control" aria-describedby="sizing-addon1" placeholder="Другой сайт" >
#                     <span class="input-group-btn">
#                         <button class="btn btn2">Анализ</button>
#                     </span>
#                 </div>
#                 <div class="alert alert-danger fade in alert-dismissable hidden"></div>
#             </form>
#         </div>
#     </div>
#     -->
# <div class="row border_top_grey1">
# <div class="col-md-1 padding_left padding_right40">
# <!-- MENU -->
# <aside class="sideLeft" id="aside1">
# <div id="navbar">
# <ul class="nav_menu">
# <li><a href="/stat/misis.ru#top"><i class="fa fa-sitemap fa-fw"></i><br/>Информация<br/>о сайте</a></li>
# <li><a href="/stat/misis.ru#menu_index"><i class="fa fa-bar-chart fa-fw"></i><br/>Индексация<br/>сайта</a></li>
# <li><a href="/stat/misis.ru#menu_visrep"><i class="fa fa-search fa-fw"></i><br/>Видимость<br/>сайта</a></li>
# <li><a href="/stat/misis.ru#menu_links"><i class="fa fa-link fa-fw"></i><br/>Ссылки</a></li>
# <li><a href="/stat/misis.ru#menu_mobil"><i class="fa fa-tablet fa-fw"></i><br/>Проверка на<br/>мобильность</a></li>
# <li><a href="/stat/misis.ru#menu_seo"><i class="fa fa-bullseye fa-fw"></i><br/>SEO</a></li>
# <li><a href="/stat/misis.ru#menu_similar"><i class="fa fa-users fa-fw"></i><br/>Динамика<br/>посещаемости</a></li>
# <li><a href="/stat/misis.ru#menu_competitors"><i class="fa fa-handshake-o fa-fw"></i><br/>Конкуренты</a></li>
# <li><a href="/stat/misis.ru#menu_whois"><i class="fa fa-vcard fa-fw"></i><br/>WHOIS</a></li>
# <li><a href="/stat/misis.ru#menu_yandex_webmaster"><i class="fa fa-yahoo fa-fw"></i><br/>Webmaster</a></li>
# <li>
# </li>
# </ul>
# </div>
# </aside>
# <!-- MENU -->
# </div>
# <div class="col-md-11" id="report">
# <!-- SITE INFO -->
# <div class="plate">
# <div class="plate-heading">
# <i class="fa fa-sitemap fa-fw"></i> Информация о сайте
#                 </div>
# <div class="plate-content">
# <div class="block">
# <div class="row" style="margin-right: -20px;">
# <div class="col-sm-12 hidden-md hidden-lg text-center">
# <div class="imac2">
# <div id="set_screenshot_desktop2">
# <img src="/uploads/sites/misis.ru/screenshot_desktop.jpg"/> </div>
# </div>
# </div>
# <div class="col-md-8 col-lg-9">
# <div class="row margin_top20">
# <div class="col-md-1 col-sm-2 col-xs-2">
# <div class="size margin_left15 padding_top10"><span aria-hidden="true" class="glyphicon glyphicon-tags col_w_green font1_3"></span></div>
# </div>
# <div class="text col-md-11 col-sm-10 col-xs-10">
# <div class="col_w_green font16 float_left">
#                                             Title
#                                             <sup>(<span id="set_title_length">55</span>)</sup>
# </div>
# <div class="clearfix"></div>
# <div id="set_title">Университет науки и технологий МИСИС — официальный сайт</div>
# </div>
# </div>
# <div class="row margin_top20">
# <div class="col-md-1 col-sm-2 col-xs-2">
# <div class="size margin_left15 padding_top10"><span aria-hidden="true" class="glyphicon glyphicon-pencil col_w_green font1_3"></span></div>
# </div>
# <div class="text col-md-11 col-sm-10 col-xs-10">
# <div class="col_w_green font16 float_left">
#                                             Description
#                                             <sup>(<span id="set_description_length">115</span>)</sup>
# </div>
# <div class="clearfix"></div>
# <div id="set_description">Университет науки и технологий МИСИС в Москве: информация для поступающих, новости, институты, программы подготовки</div>
# </div>
# </div>
# <div class="row margin_top20">
# <div class="col-md-1 col-sm-2 col-xs-2">
# <div class="size margin_left15 padding_top10">
# <div class="ico_keywords"></div>
# </div>
# </div>
# <div class="text col-md-10 col-sm-10 col-xs-10">
# <h4 class="col_w_green">Keywords</h4>
# <div id="set_keywords">Тег не заполнен</div>
# </div>
# </div>
# <div class="row margin_top20 margin_bottom20">
# <div class="col-md-1 col-sm-2 col-xs-2">
# <div class="size margin_left15 padding_top5 col_w_green font_bold"><span class="font20">H</span>1</div>
# </div>
# <div class="text col-md-10 col-sm-10 col-xs-10">
# <h4 class="col_w_green">Заголовки</h4>
# <div id="set_headers"><div class="hx_headers">
# <div class="float_left height20"><span class="black2">H1:</span> 1</div>
# <div class="float_left margin_left10 height20"><span class="black2">H2:</span> <span class="g_red">0</span></div>
# <div class="float_left margin_left10 height20"><span class="black2">H3:</span> 3</div>
# <div class="float_left margin_left10 height20"><span class="black2">H4:</span> <span class="g_red">0</span></div>
# <div class="float_left margin_left10 height20"><span class="black2">H5:</span> 2</div>
# <div class="float_left margin_left10 height20"><span class="black2">H6:</span> 0</div>
# </div>
# </div>
# <div class="text-danger mobile-app-hidden" style="position: absolute; bottom: -20px;"><i class="fa fa-exclamation-triangle"></i> <a class="text-danger" href="/audit/" onclick="logErrorAudit()">Обнаружено 45 технических ошибок</a></div>
# </div>
# </div>
# </div>
# <div class="col-md-4 col-lg-3 hidden-xs hidden-sm" style="overflow-x: hidden; height: 330px; margin-top: -80px;">
# <base href="https://be1.ru"/>
# <div class="imac" id="imac">
# <div id="set_screenshot_desktop">
# <img src="/uploads/sites/misis.ru/screenshot_desktop.jpg"/> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="block no-paddings general-columns">
# <div class="column">
# <div class="icon"><i class="icon-be1-13"></i></div>
# <div class="text">
# <span>Возраст домена</span><br/>
# <a href="/proverka-whois/?domain=misis.ru" id="set_vozrast" target="_blank">23 года 364 дня</a>
# </div>
# </div>
# <div class="column">
# <div class="icon"><i class="icon-be1-17"></i></div>
# <div class="text">
# <span>Размер страницы</span>
# <div id="set_page_size">50.38 КБ</div>
# </div>
# </div>
# <div class="column">
# <div class="icon"><i class="icon-be1-12"></i></div>
# <div class="text">
# <span>Скорость загрузки</span><br/>
# <a href="/site-speed/?url=misis.ru" id="set_page_load_time" target="_blank">2100 сек</a>
# </div>
# </div>
# <div class="column">
# <div class="icon"><i class="icon-be1-19"></i></div>
# <div class="text">
# <span>IP адрес</span>
# <div id="set_site_ip">5.253.61.53</div>
# </div>
# </div>
# <div class="column">
# <div class="icon"><i class="icon-be1-9"></i></div>
# <div class="text">
# <span>Стоимость сайта</span><br/>
# <a href="/site-cost/?url=misis.ru" id="set_site_cost" target="_blank">213 660 руб.</a>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="banner_container text-center div_center" style="max-height: 120px; max-width: 720px; margin-bottom: 10px;">
# <!-- yandex_rtb_R-A-2104376-2 -->
# <div id="yandex_banner_08"></div>
# <script>
# 				window.yaContextCb.push(() => {
# 					Ya.Context.AdvManager.render({
# 						renderTo: 'yandex_banner_08',
# 						blockId: 'R-A-2104376-2'
# 					})
# 				})
# 			</script>
# </div>
# <!-- YANDEX / GOOGLE / MEGAINDEX -->
# <div class="row margin_bottom10" id="menu_index"></div>
# <div class="plate">
# <div class="plate-heading">
# <i class="fa fa-bar-chart fa-fw"></i> Индексация сайта
#
#                     <div class="right mobile-app-hidden" style="font-size: 14px; color: #7f8c8d; padding-top: 5px;">
# <!-- Продвинь сайт с помощью. <a href="http://start.megaindex.ru/" target="_blank"> <img src="/template/be1/images/miseo.png" alt="megaindex_logo"></a> -->
# <div class="text_center banner_container">
# <a data-banner="4" data-goalname="" data-href="http://start.megaindex.ru/" href="#" target="_blank">
# <img alt="MegaIndex" class="" src="/uploads/banners/place_4.png?v=202309283934" style="height: 15px; width: 160px;"/>
# </a>
# <!--a href="/advertising/" title="Заказать рекламу на этом месте" class="banner_link" style="right: 58px"><i class="fa fa-plus-square-o background_white"></i></a-->
# </div> </div>
# </div>
# <div class="plate-content">
# <div class="block no-paddings indexing">
# <div class="column">
# <img class="title-img" src="/template/be1/images/yandex_logo.svg"/>
# <table class="table">
# <tbody>
# <tr>
# <td>
#                                             Проиндексировано
#                                             <div class="about my_tooltip" href="https://be1.ru/faq/pokazateli-yandex/" target="_blank">
# <div class="ico"><span class="tooltiptext">Количество страниц сайта в поисковой выдаче Яндекс. Определяется при помощи запроса вида url:адрес-сайта*. Обновляется, примерно, раз в месяц.<div class="float_right margin_top5"><a class="" href="https://yandex.ru/support/webmaster/adding-site/indexed-pages.xml?lang=ru" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span></div>
# </div>
# </td>
# <td id="set_pages_in_yandex">
# <span class="clickable" onclick="show_pages_index_history('yandex')" style="margin-right: 10px; color: #FF7C52;" title="История изменения"><i class="fa fa-line-chart"></i></span>
# <a href="https://yandex.ru/search/?text=site:misis.ru" target="_blank">2641</a>
# <script>
# setTimeout(function () {
#     $('#set_pages_in_yandex').next().html('&nbsp;<div class="text-danger sup-change" data-toggle="tooltip" title="История изменений" onclick="show_pages_index_history(\'yandex\')">-854</div>');
# }, 100);
# </script>
# <script>
# var yandex_pages_index_history = [["2019-10-15",28936],["2020-01-17",26176],["2020-04-12",22666],["2020-05-06",22883],["2020-05-21",21879],["2020-06-23",23139],["2020-07-04",23048],["2020-07-22",22780],["2020-08-03",23626],["2020-08-21",23480],["2020-10-13",44910],["2020-10-19",44865],["2020-11-17",43604],["2020-11-20",44256],["2020-11-22",44439],["2020-11-30",45958],["2020-12-19",45319],["2021-04-14",45499],["2021-04-21",45264],["2021-07-10",45170],["2021-08-12",39654],["2021-08-19",45087],["2021-08-26",43797],["2021-09-08",2696],["2021-09-10",44649],["2021-09-16",2938],["2021-09-20",3131],["2021-09-22",3150],["2021-09-28",2788],["2021-10-06",4040],["2021-10-08",3914],["2021-10-18",3274],["2021-10-23",2473],["2021-10-28",2784],["2021-10-30",2689],["2021-11-11",3014],["2021-11-19",3063],["2021-11-21",3440],["2021-11-25",3498],["2021-11-30",3099],["2021-12-05",3289],["2022-01-08",2483],["2022-01-13",2839],["2022-03-20",5918],["2022-03-28",4286],["2022-04-03",9432],["2022-04-22",3772],["2022-05-02",3227],["2022-05-09",2934],["2022-06-21",796],["2022-06-24",639],["2022-07-08",1246],["2022-07-11",1567],["2022-07-31",913],["2022-08-28",2714],["2022-09-08",3557],["2022-09-14",2587],["2022-10-20",2549],["2023-02-06",2034],["2023-03-06",5037],["2023-06-06",18649],["2023-06-25",3495],["2023-09-28",2641]];
# </script>
# </td>
# <td></td>
# </tr>
# <tr>
# <td>
#                                             Яндекс ИКС
#                                             <div class="about my_tooltip" href="/faq/pokazateli-yandex/" target="_blank">
# <div class="ico"></div><span class="tooltiptext">Индекс качества сайта — это показатель того, насколько полезен ваш сайт для пользователей с точки зрения Яндекса.<div class="float_right margin_top5"><a class="" href="https://yandex.ru/support/webmaster/site-quality-index.html" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span>
# </div>
# </td>
# <td id="set_iks">
# <span class="clickable" onclick="show_iks_history()" style="margin-right: 10px; color: #FF7C52;" title="История изменения ИКС"><i class="fa fa-line-chart"></i></span>
# <a href="https://webmaster.yandex.ru/sqi/?host=misis.ru" id="set_iks" target="_blank">6600</a>
# <script>
# setTimeout(function () {
#     $('#set_iks').next().html('&nbsp;<div class="text-success sup-change" data-toggle="tooltip" title="История ИКС" onclick="show_iks_history()">+6600</div>');
# }, 100);
# </script>
# <script>
# var iks_history = {"2018-09-03":2500,"2018-12-24":2500,"2019-02-26":2900,"2019-03-27":2900,"2019-04-19":3000,"2019-05-24":3000,"2019-06-25":3000,"2019-07-30":3100,"2019-08-27":3140,"2019-09-27":3170,"2019-10-29":3250,"2019-11-29":3320,"2019-12-27":3390,"2020-01-30":3440,"2020-02-28":3470,"2020-03-27":3520,"2020-04-29":3800,"2020-05-27":4180,"2020-06-25":4540,"2020-07-30":4600,"2020-08-28":4730,"2020-09-24":4880,"2020-11-05":5150,"2021-02-25":6800,"2021-03-15":6900,"2021-03-26":250,"2021-04-16":7000,"2021-04-30":7000,"2021-05-18":7000,"2021-05-27":6950,"2021-06-11":6950,"2021-06-28":6850,"2021-07-10":6900,"2021-07-16":6900,"2021-08-02":7000,"2021-08-13":6950,"2021-08-30":6900,"2021-09-11":6900,"2021-09-30":6900,"2021-10-12":6900,"2021-10-22":6850,"2021-11-01":6850,"2021-11-08":6900,"2021-11-16":6900,"2021-11-25":6900,"2021-12-03":6850,"2022-01-10":6750,"2022-02-07":6650,"2022-02-21":6650,"2022-03-05":6600,"2022-03-25":6600,"2022-03-31":6600,"2022-04-07":6600,"2022-05-19":6600,"2022-06-29":6650,"2022-07-19":6650,"2022-08-09":6500,"2022-09-14":6500,"2022-10-06":6500,"2022-10-27":6550,"2022-12-07":6750,"2023-04-06":0,"2023-07-03":6600};
# </script>
# </td>
# <td></td>
# </tr>
# <tr>
# <td>
#                                             Фильтр за вирусы
#                                             <div class="about my_tooltip">
# <div class="ico"></div><span class="tooltiptext">Обнаружено ли поисковой системой Яндекс, вредоносный код на сайте.<div class="float_right margin_top5"><a class="" href="/proverka-virus/?text=misis.ru" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span>
# </div>
# </td>
# <td>
# <a href="https://be1.ru/proverka-virus/?url=be1.ru" id="set_virus" target="_blank">Нет</a>
# </td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="column">
# <img class="title-img" src="/template/be1/images/Logo_Google.svg"/>
# <table class="table">
# <tbody>
# <tr>
# <td>
#                                             Проиндексировано
#                                             <div class="about my_tooltip" href="/faq/pokazateli-google/" target="_blank">
# <div class="ico"></div><span class="tooltiptext">Количество страниц сайта в поисковой выдаче Google. Определяется при помощи запроса вида site:адрес-сайта. Обновляется, примерно, раз в месяц.<div class="float_right margin_top5"><a class="" href="https://support.google.com/websearch/answer/2466433?hl=ru" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span>
# </div>
# </td>
# <td id="set_pages_in_google">
# <span class="clickable" onclick="show_pages_index_history('google')" style="margin-right: 10px; color: #FF7C52;" title="История изменения"><i class="fa fa-line-chart"></i></span>
# <a href="http://www.google.ru/search?q=site%3Amisis.ru" target="_blank">80500</a>
# <script>
# setTimeout(function () {
#     $('#set_pages_in_google').next().html('&nbsp;<div class="text-danger sup-change" data-toggle="tooltip" title="История изменений" onclick="show_pages_index_history(\'google\')">-32500</div>');
# }, 100);
# </script>
# <script>
# var google_pages_index_history = [["2019-10-15",90700],["2020-04-12",89100],["2020-05-06",83200],["2020-05-21",85900],["2020-06-23",1280000],["2020-07-04",773000],["2020-07-22",103000],["2020-08-03",107000],["2020-08-21",97100],["2020-10-13",84500],["2020-10-19",87200],["2020-11-17",110000],["2020-11-20",91300],["2020-11-22",98200],["2020-11-30",94600],["2020-12-19",90800],["2021-04-06",85800],["2021-04-14",94800],["2021-04-21",132000],["2021-07-10",89700],["2021-08-12",83200],["2021-08-19",93100],["2021-08-26",82000],["2021-09-08",88200],["2021-09-10",85100],["2021-09-16",89000],["2021-09-20",95100],["2021-09-22",86200],["2021-09-28",114000],["2021-10-06",111000],["2021-10-08",86200],["2021-10-18",93200],["2021-10-23",121000],["2021-10-28",102000],["2021-10-30",84400],["2021-11-11",119000],["2021-11-19",87700],["2021-11-21",83600],["2021-11-25",83900],["2021-11-30",78900],["2021-12-05",81200],["2022-01-08",109000],["2022-01-13",85100],["2022-03-20",92900],["2022-03-28",87700],["2022-04-03",90500],["2022-04-22",88200],["2022-05-02",86500],["2022-05-09",87100],["2022-06-21",107000],["2022-06-24",111000],["2022-07-08",102000],["2022-07-11",105000],["2022-07-31",113000],["2022-08-28",90100],["2022-09-08",83000],["2022-09-14",80800],["2022-10-20",113000],["2023-02-06",80500]];
# </script>
# </td>
# <td></td>
# </tr>
# <tr>
# <td>
#                                             Скорость загрузки
#                                             <div class="about my_tooltip" href="/faq/pokazateli-google/" target="_blank">
# <div class="ico"></div><span class="tooltiptext">Проверка скорости загрузки элементов сайта на Компьютере/Мобильном. Выполняется инструментом Google PageSpeed Insights. Оценка может составлять от 0 до 100 баллов.<div class="float_right margin_top5"><a class="" href="https://developers.google.com/speed/docs/insights/about" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span>
# </div>
# </td>
# <td>
# <a href="https://developers.google.com/speed/pagespeed/insights/?hl=ru&amp;url=misis.ru&amp;tab=desktop" id="set_google_speed_desktop" target="_blank"><img src="/template/be1/images/ajax-loader.gif"/></a>
#                                             /
#                                             <a href="https://developers.google.com/speed/pagespeed/insights/?hl=ru&amp;url=misis.ru&amp;tab=mobile" id="set_google_speed_mobile" target="_blank"><img src="/template/be1/images/ajax-loader.gif"/></a>
# </td>
# <td></td>
# </tr>
# <tr>
# <td style="border-top: none;"> </td>
# <td style="border-top: none;"> </td>
# <td style="border-top: none;"></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="column">
# <img class="title-img" src="/template/be1/images/Logo_MegaIndex.svg"/>
# <table class="table">
# <tbody>
# <tr>
# <td>
#                                             Megaindex Trust Rank
#                                             <div class="about my_tooltip" href="https://www.megaindex.org/serp_backlinks" target="_blank">
# <div class="ico"></div><span class="tooltiptextL">Степень доверия поисковой системы к сайту. Рассчитывается по алгоритму, аналогичному Page Rank, но учитывает только ссылочный граф между доменами.<div class="float_right margin_top5"><a class="" href="https://www.megaindex.org/serp_backlinks" target="_blank">подробнее<div class="nonedecoration inline_block"> </div><span aria-hidden="true" class="glyphicon glyphicon-forward col_w_green font9 nonedecoration"></span></a></div></span>
# </div>
# </td>
# <td id="set_trust_rank">
#                                             38                                        </td>
# <td></td>
# </tr>
# <tr>
# <td>
#                                             Megaindex Domain Rank
#                                             <div class="about my_tooltip" href="#" target="_blank">
# <div class="ico"></div><span class="tooltiptextL">Показатель, который рассчитывается по формуле:<br/>Log5(IP*0.75 + 1)<br/>IP — число ссылающихся уникальных веб-серверов на донор.</span>
# </div>
# </td>
# <td>
# <a href="https://ru.megaindex.com/a/domainrank?domain=misis.ru" id="set_domain_rank" target="_blank">41</a>
# </td>
# <td></td>
# </tr>
# <tr>
# <td style="border-top: none;"> </td>
# <td style="border-top: none;"> </td>
# <td style="border-top: none;"></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </div>
# <!-- VISREP -->
# <div class="row margin_bottom10" id="menu_visrep"></div>
# <div class="plate">
# <div class="plate-heading">
# <i class="fa fa-search fa-fw"></i> Видимость сайта
#
#                     <div class="right" style="font-size: 14px; color: #7f8c8d; padding-top: 5px;">
# </div>
# </div>
# <div class="plate-content">
# <div class="block" id="set_visrep_site_counters_yandex">
# <script type="text/javascript">
#     //google.charts.load('current', {'packages':['corechart']});
#     google.charts.setOnLoadCallback(VisrepDrawChart);
#     function VisrepDrawChart() {
#         var data = google.visualization.arrayToDataTable([
#             ['Year', 'Количество запросов', 'Количество эффективных показов'],
#             ['Август',  298, 11256],['Сентябрь',  224, 11027],['Октябрь',  231, 11397],['Ноябрь',  282, 10524],['Декабрь',  274, 10685],['Январь',  211, 8427],['Февраль',  287, 12327],['Март',  304, 10272],['Апрель',  27, 8059],['Май',  31, 7814],['Июнь',  12, 196],['Июль',  230, 806],        ]);
#
#
#         var options = {
# 			vAxes: {
# 				0: {
# 					gridlines: {
# 						color: '#ededed',
# 					},
# 					minorGridlines: {
# 						count: 0,
# 					},
# 				},
# 				1: {
# 					gridlines: {
# 						color: 'transparent',
# 					},
# 					minorGridlines: {
# 						count: 0,
# 					},
# 				},
# 			},
#
#             legend :'none',
#             pointSize: 5,
#             series: {
#                 0: {
#                     color: '#F47264',
#                     areaOpacity: 0,
#                     targetAxisIndex:1,
#                 },
#                 1: {
#                     color: '#00AAB1',
#                     targetAxisIndex:0,
#                 },
#             },
#             height: 300,
#             backgroundColor: 'transparent',
#             chartArea: {
# 				left: 70,
# 				right: 70,
# 				height: '70%'
# 			},
#         };
#
#         var visrep_grafik = new google.visualization.AreaChart(document.getElementById('chart_div'));
#
#         // Wait for the chart to finish drawing before calling the getImageURI() method.
#         google.visualization.events.addListener(visrep_grafik, 'ready', function () {
#             //$('#visrep_grafik_imsge').html('<img src="' + visrep_grafik.getImageURI() + '">');
#             $('#visrep_grafik_imsge').html(visrep_grafik.getImageURI());
#             //console.log($('#pdf_editor').innerHTML);
#             //console.log(visrep_grafik.getImageURI());
#         });
#
#         visrep_grafik.draw(data, options);
#     }
# </script>
# <style>
# #chart_div svg > g:nth-child(2) > g:last-child > g:nth-last-child(-n+10) text {
# 	fill: #00AAB1;
# }
# #chart_div svg > g:nth-child(2) > g:last-child > g:nth-last-child(-n+5) text {
# 	fill: #F47264;
# }
# </style>
# <div class="margin_bottom20">
# <div class="">
# <span class="h3">Динамика видимости | </span>
# <a href="https://ru.megaindex.com/visibility/misis.ru/report?ser_id=1®ion=&amp;pg=0" target="_blank">Детальный отчет</a>
# </div>
# </div>
# <div class="row">
# <div class="col-md-2 extension-padding-left0">
# <div class="ico_logo_ya height20"></div>
# </div>
# </div>
# <div class="row">
# <div class="padding_right5 padding_left5" id="chart_div"></div>
# <div class="display_none" id="visrep_grafik_imsge"></div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-sm-5 col-md-5 margin_top5 extension-margin-top10">
# <ul>
# <li><div class="background_orang width15 float_left margin_right5"> </div>Количество запросов<div class="about my_tooltip" href="/faq/visibility/" target="_blank">
# <div class="ico"></div>
# <span class="tooltiptext">
#                        Частотность ввода ключевых слов из видимости сайта в поиске Яндекс за месяц, согласно данным <a class="" href="https://wordstat.yandex.ua/" target="_blank">Wordstat</a>
# </span>
# </div></li>
# <li class="margin_top7"><div class="background_w_green width15 float_left margin_right5"> </div>Количество эффективных показов<div class="about my_tooltip" href="/faq/visibility/" target="_blank">
# <div class="ico"></div>
# <span class="tooltiptext">
#                             Количество показов пользователям сниппетов сайта в выдаче Яндекса, согласно данным о видимости сайта.<br/>
# Рассчитывается по коэффициенту позиции:<br/>
# 1-3 позиции – 100% <br/>
# 4-5 позиции – 70% <br/>
# 6-10 позиции – 50% <br/>
# 11-20 позиции – 10% <br/>
# 21-50 позиции – 3% <br/>
# 51-100 позиции – 1%<br/>
# </span>
# </div></li>
# </ul>
# </div>
# <div class="col-xs-6 col-sm-3 text_left margin_top10 border_rl_dotted_adaptiv">
# <div class="font_visrepadaptiv">230</div>
# <div>Запросов  (ТОП 10)</div>
# </div>
# <div class="col-xs-6 col-sm-3 text_left margin_top10">
# <div class="font_visrepadaptiv">806</div>
# <!--visrep_site_counters_ya['eff_volume']-->
# <div>Эфф. показов</div>
# </div>
# </div>
# </div>
# <div class="block">
# <!-- Nav tabs -->
# <ul class="nav nav-tabs" id="visrep_tabs" role="tablist">
# <li class="active" role="presentation"><a aria-controls="home" data-section="visrep_table" data-toggle="tab" href="#set_visrep_yandex" role="tab"><span class="ya">Y</span>andex</a></li>
# <li class="" role="presentation"><a aria-controls="profile" data-section="visrep_table" data-toggle="tab" href="#set_visrep_google" role="tab">
# <div class="google"><span>G</span><span>o</span><span>o</span><span>g</span><span>l</span><span>e</span></div>
# </a></li>
# </ul>
# <!-- Tab panes -->
# <div class="tab-content padding_top10">
# <div class="tab-pane active" id="set_visrep_yandex" role="tabpanel">
# <div class="styled-table">
# <div class="table-responsive">
# <table class="table main">
# <thead>
# <tr>
# <th>№</th>
# <th>Запрос</th>
# <th class="text-center" style="width: 80px;">Позиция<!--<br><span class="pos-date">28.09.2023</span>--></th>
# <th class="hidden-sm hidden-xs">URL</th>
# <th class="text-center">Запросов в месяц</th>
# <th class="text-center">Эфф. показов</th>
# <th class="text-center hidden-sm hidden-xs">Конкурентный анализ</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td data-label="#">1</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(0)">мисис</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">2380</td>
# <td class="text-center" data-label="Эфф.показов">2380</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('мисис')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">2</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(1)">миссис</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">1600</td>
# <td class="text-center" data-label="Эфф.показов">1600</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('миссис')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">3</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(2)">горный</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												4
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/university/struktura-universiteta/instituty/gi/" target="_blank">/university/struktura-universiteta/instituty/gi/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">1971</td>
# <td class="text-center" data-label="Эфф.показов">1380</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('горный')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">4</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(3)">горный университет</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												9
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/university/struktura-universiteta/instituty/gi/" target="_blank">/university/struktura-universiteta/instituty/gi/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">1175</td>
# <td class="text-center" data-label="Эфф.показов">588</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('горный университет')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">5</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(4)">ниту мисис</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">559</td>
# <td class="text-center" data-label="Эфф.показов">559</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('ниту мисис')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">6</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(5)">мисис официальный сайт</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">247</td>
# <td class="text-center" data-label="Эфф.показов">247</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('мисис официальный сайт')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">7</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(6)">ниту мисис официальный сайт</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">234</td>
# <td class="text-center" data-label="Эфф.показов">234</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('ниту мисис официальный сайт')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">8</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(7)">горный институт</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												2
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/university/struktura-universiteta/instituty/gi/" target="_blank">/university/struktura-universiteta/instituty/gi/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">233</td>
# <td class="text-center" data-label="Эфф.показов">233</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('горный институт')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">9</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(8)">бизнес информатика</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												7
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/applicants/admission/baccalaureate-and-specialty/faculties/bi/" target="_blank">/applicants/admission/baccalaureate-and-specialty/faculties/bi/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">381</td>
# <td class="text-center" data-label="Эфф.показов">191</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('бизнес информатика')">отчёт</a></td>
# </tr>
# <tr>
# <td data-label="#">10</td>
# <td data-label="Запрос">
# <div>
# <a data-target="#yandex_visrep_details_modal" data-toggle="modal" href="#" onclick="show_yandex_visrep_details(9)">национальный исследовательский технологический университет мисис</a>
# </div>
# </td>
# <td class="text-center" data-label="Позиция" style="position: relative;">
#
# 												1
# 											</td>
# <td class="" data-label="URL"><div class="obrezat"><a href="http://misis.ru/" target="_blank">/</a></div></td>
# <td class="text-center" data-label="Запросов в месяц">187</td>
# <td class="text-center" data-label="Эфф.показов">187</td>
# <td class="text-center" data-label="Конкур.анализ"><a class="btn-sapphire" data-target="#analiz-konkurentov-modal" data-toggle="modal" href="#" onclick="$('#analiz-konkurentov-modal input[name=query]').val('национальный исследовательский технологический университет мисис')">отчёт</a></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <!-- Modal -->
# <div class="modal fade" id="yandex_visrep_details_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <span class="modal-title">Запрос: <em></em></span>
# </div>
# <div class="modal-body">
# <select class="form-control" onchange="change_yandex_visrep_view($(this).val())">
# <option value="domain">Показывать только домены</option>
# <option value="url">Показывать URL полностью</option>
# </select>
# <br/>
# <div></div>
# </div>
# </div>
# </div>
# </div>
# <!-- Modal -->
# <div class="modal fade" id="yandex_visrep_history_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <span class="modal-title">Запрос: <em></em></span>
# </div>
# <div class="modal-body text-center">
# <span class="h3">История позиций</span>
# <div></div>
# </div>
# </div>
# </div>
# </div>
# <script>
# var yandex_visrep = {
#
#
# 	0: {
# 		text: 'мисис',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	1: {
# 		text: 'миссис',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	2: {
# 		text: 'горный',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	3: {
# 		text: 'горный университет',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	4: {
# 		text: 'ниту мисис',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	5: {
# 		text: 'мисис официальный сайт',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	6: {
# 		text: 'ниту мисис официальный сайт',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	7: {
# 		text: 'горный институт',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	8: {
# 		text: 'бизнес информатика',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
#
#
# 	9: {
# 		text: 'национальный исследовательский технологический университет мисис',
# 		urls: [''],
# 		history: {
# 											}
# 	},
#
# 	};
#
# function show_yandex_visrep_details(i) {
# 	$('#yandex_visrep_details_modal .modal-title em').text(yandex_visrep[i].text);
#
# 	if(yandex_visrep[i].urls.length == 1) {
# 		$('#yandex_visrep_details_modal .modal-body > div').html('Нет информации...<br><br>');
# 		$('#yandex_visrep_details_modal select').addClass('hidden');
# 		return;
# 	}
#
# 	var table = '' +
# 		'<table class="table table-bordered table-fixed table-headed">' +
# 			'<thead>' +
# 				'<tr>' +
# 					'<th class="text-center" style="width: 40px;">#</th>' +
# 					'<th>Yandex</th>' +
# 				'</tr>' +
# 			'</thead>' +
# 			'<tbody>';
#
# 	yandex_visrep[i].urls.forEach(function(url, j) {
# 		var domain = get_domain(url);
# 		style = '';
# 		if (domain=='misis.ru') style ='success';
# 		table += '' +
# 			'<tr class='+style+'>' +
# 				'<td class="text-center">'+(j+1)+'</td>' +
# 				'<td domain="'+domain+'" url="'+url+'"><a href="'+url+'" target="_blank" class="text-ellipsis">'+domain+'</a></td>' +
# 			'</tr>';
# 	});
#
# 	table += '</tbody></table>';
#
# 	table += '<button onclick="save_yandex_visrep_details_to_csv('+i+')" class="btn btn-success"><i class="fa fa-download"></i>&nbsp; Скачать .csv</button>';
#
# 	$('#yandex_visrep_details_modal .modal-body > div').html(table);
#
# 	$('#yandex_visrep_details_modal select').removeClass('hidden');
# }
#
# function change_yandex_visrep_view(view) {
# 	$('#yandex_visrep_details_modal table td:last-child').each(function() {
# 		$(this).html('<a href="'+$(this).attr('url')+'" target="_blank" class="text-ellipsis">'+$(this).attr(view)+'</a>');
# 	});
# }
#
# function save_yandex_visrep_details_to_csv(i) {
# 	var csv = new CSV();
#
# 	csv.addRow('Бесплатно создано при помощи: https://be1.ru/position-yandex-google/');
# 	csv.addRow();
#
# 	// create title row
# 	csv.addRow('Запрос: '+yandex_visrep[i].text);
# 	csv.addRow();
#
# 	csv.addRow('Yandex');
#
# 	// add results rows
# 	yandex_visrep[i].urls.forEach(function(url) {
# 		csv.addRow(url);
# 	});
#
# 	var blob = new Blob([csv.toString()], {type: 'text/csv;charset=utf-8'});
#
# 	var filename = 'positions_yandex_'+Date.ymd()+'.csv';
#
# 	saveAs(blob, filename);
# }
#
# /* HISTORY */
# ...
# <a href="/grupirovka-zaprosov/">
# <div><i class="icon-be1-25"></i></div>
# <div class="name">Группировка поисковых запросов</div>
# <div class="text">Сеошник спит, работа кипит!</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="3">
# <a href="/vozrast-stranicy/">
# <div><i class="icon-be1-13"></i></div>
# <div class="name">Определить возраст страницы</div>
# <div class="text">Узнайте дату, когда Яндекс впервые нашел документ</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="1" data-id="19">
# <a href="/vfacen/">
# <div><i class="icon-be1-8"></i></div>
# <div class="name">Оценка тошноты страницы</div>
# <div class="text">Оцените уровень текстового спама страницы</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="53">
# <a href="/regionalnost-sayta/">
# <div><i class="icon-be1-38"></i></div>
# <div class="name">Определение региональности сайта</div>
# <div class="text">Узнайте где привязан проект, есть ли бонус в ранжировании</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="20">
# <a href="/site-cost/">
# <div><i class="icon-be1-9"></i></div>
# <div class="name">Оценка стоимости сайта</div>
# <div class="text">Автоматический расчет рыночной цены по формуле</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="2" data-id="1">
# <a href="/affiliation/">
# <div><i class="icon-be1-17"></i></div>
# <div class="name">Аффилированность сайтов</div>
# <div class="text">Присутствует ли фильтр пессимизации на одном из сайтов</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="22">
# <a href="/speed-test-internet/">
# <div><i class="icon-be1-5"></i></div>
# <div class="name">Проверка скорости интернет</div>
# <div class="text">Тестирование соединения на скорость</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="10">
# <a href="/uznat-poddomeni-saita/">
# <div><i class="icon-be1-15"></i></div>
# <div class="name">Узнать поддомены сайта</div>
# <div class="text">Получите список поддоменов в 2 клика</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="2" data-id="5">
# <a href="/proverka-na-perespam/">
# <div><i class="icon-be1-20"></i></div>
# <div class="name">Проверка на фильтр переспам</div>
# <div class="text">Определяет наличие санкций со стороны Яндекса</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="48">
# <a href="/password-generator/">
# <div><i class="icon-be1-29"></i></div>
# <div class="name">Генератор паролей онлайн</div>
# <div class="text">Быстро придумает безопасный пароль нужной длины</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="50">
# <a href="/yandex-iks/">
# <div><i class="icon-be1-40"></i></div>
# <div class="name">Яндекс ИКС</div>
# <div class="text">Проверка индекса качества сайтов по новому алгоритму</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="41">
# <a href="/podschet-kolichestva-simvolov/">
# <div><i class="icon-be1-24"></i></div>
# <div class="name">Подсчет количества символов</div>
# <div class="text">Определяет точную длинну проверяемого текста</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="47">
# <a href="/transliteratsiya/">
# <div><i class="icon-be1-32"></i></div>
# <div class="name">Транслитерация онлайн</div>
# <div class="text">Преобразует русские буквы (кириллицу) в латиницу (английские)</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="2" data-id="21">
# <a href="/proverka-virus/">
# <div><i class="icon-be1-7"></i></div>
# <div class="name">Проверка сайтов на вирусы</div>
# <div class="text">Находятся ли Ваши ресурсы под фильтром Яндекса за вирусы</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="9">
# <a href="/html-redaktor-online/">
# <div><i class="icon-be1-22"></i></div>
# <div class="name">Визуальный HTML редактор онлайн</div>
# <div class="text">Позволяет ускорить процесс написания кода</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="7">
# <a href="/proverit-skleyku-domenov/">
# <div><i class="icon-be1-23"></i></div>
# <div class="name">Проверить склейку доменов</div>
# <div class="text">Массовый чек адресов на "клей" в Яндексе</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="1" data-id="17">
# <a href="/otvet-servera/">
# <div><i class="icon-be1-6"></i></div>
# <div class="name">Проверка заголовков сервера</div>
# <div class="text">Проверка ответов сервера, HTTP заголовков</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="14">
# <a href="/proverka-whois/">
# <div><i class="icon-be1-18"></i></div>
# <div class="name">WHOIS</div>
# <div class="text">Информация о доменах: дата регистрации, проверка на занятость</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="8">
# <a href="/generator-favicon/">
# <div><i class="icon-be1-2"></i></div>
# <div class="name">Favicon.ico генератор</div>
# <div class="text">Создание фавиконки для вашего ресурса онлайн</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="1" data-id="16">
# <a href="/site-speed/">
# <div><i class="icon-be1-12"></i></div>
# <div class="name">Анализ скорости сайта</div>
# <div class="text">Проверка скорости отклика хостинга или сервера</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="63">
# <a href="/my-ip/">
# <div><i class="icon-be1-19"></i></div>
# <div class="name">Мой IP</div>
# <div class="text">Узнать IP адрес и данные о браузере своего компьютера</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="4" data-id="62">
# <a href="/cms/">
# <div><i class="icon-be1-41"></i></div>
# <div class="name">Определить CMS</div>
# <div class="text">Узнайте на каком движке сделан любой сайт в интернете</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="5" data-id="67">
# <a href="/sintaksicheskij-razbor-predlozheniya/">
# <div><i class="icon-be1-44"></i></div>
# <div class="name">Синтаксический разбор предложения</div>
# <div class="text">Полный анализ каждого составного слова</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool" data-category="1" data-id="68">
# <a href="/morphology-analysis/">
# <div><i class="icon-be1-45"></i></div>
# <div class="name">Морфологический разбор слова</div>
# <div class="text">Анализ морфологии и грамматических признаков слова</div>
# </a>
# </div>
# <div class="col-xs-6 col-sm-4 col-md-2 col-lg-2 tool suggest">
# <a class="cursor_hand tool_new_message">
# <div><i class="icon-be1-21"></i></div>
# <div class="name">Предложить свой инструмент</div>
# <div class="text big_screen_only">Напишите нам, какого функционала Вам не хватает</div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="modal_support_form"></div>
# <!--div class="modal" id="problem_form" tabindex="-1" role="dialog" aria-labelledby="myModalLabel">
#     <div class="modal-dialog" role="document">
#         <div class="modal-content">
#             <div class="modal-header">
#                 <span class="font24 black2" id="problem_form_header">Предложить новый инструмент!</span>
#                 <button type="button" class="close" data-dismiss="modal" aria-label="Close"><span aria-hidden="true">×</span></button>
#             </div>
#             <div class="modal-body text_center" id="problem_form_result">
#                 <div class="font16 black2 margin_bottom10" id="problem_form_title">Опишите необходимый инструмент, и мы постараемся его реализовать...</div>        <div class="margin_bottom20 "><textarea class="form-control width100p resizenone" rows="10" id="problem_text"></textarea></div>        <div><input id="problem_form_email" class="form-control width100p margin_bottom20" placeholder="Укажите Ваш email" value=""></div>        <button class="btn2" id="problem_btn">Отправить сообщение</button>                </div>
#         </div>
#     </div>
# </div-->
# <script>
# function showToolsCategoryTab(category_id) {
#      $('.tools-list .tool').hide();
#      $('.tools-list .tool[data-category=' + category_id + ']').show();
#      $('.tools-list .tool.suggest').show();
#      $('#tool-cat-all').find('.no-favorite-tools').remove();
# }
#
# function showFavoriteToolsTab() {
#     $('.tools-list .tool').hide();
#
#     let favoriteTools = $('.tools-list .tool.tool-favorite');
#
#     if (favoriteTools.length) {
#         favoriteTools.show();
#     } else {
#         $('#tool-cat-all').append('<div class="no-favorite-tools">Нет избранных...</div>');
#     }
# }
#
# function toggleToolFavorite(tool) {
#     tool.toggleClass('tool-favorite');
#
#     if (tool.is('.tool-favorite')) {
#         $.get('/ajax/tools/favorite_attach/?tool_id=' + tool.attr('data-id'));
#     } else {
#         $.get('/ajax/tools/favorite_detach/?tool_id=' + tool.attr('data-id'));
#     }
# }
# </script>
# </div>
# <div id="div_login_form"></div> <!--?=$this->load->view('be2/core/modal_login_form')?-->
# <footer>
# <div class="container">
# <div class="row">
# <div class="col-sm-12 col-md-2 margin_bottom40">
# <a href="/"><div class="logo2 logo"></div></a>
# <br/>
# <a href="/services/prodvizhenie/analyticheskie-sistemy/">Рейтинг сервисов</a><br/>
# <a href="/services/experts/">Эксперты</a><br/>
# <a href="/bookmarklet/">Букмарклеты</a><br/>
# <a href="/faq/">FAQ</a><br/>
# <a href="/api/">API</a><br/>
# <div class="footer-label">Способы оплаты:</div>
# <!-- begin WebMoney Transfer : attestation label -->
# <a class="text_center" href="https://passport.webmoney.ru/asp/certview.asp?wmid=212772183933" target="_blank"><img alt="Здесь находится аттестат нашего WM идентификатора 212772183933" border="0" class="pay" src="/template/be1/images/v_blue_on_white_ru.png"><br><span style="font-size: 0,7em;">Проверить аттестат</span></br></img></a>
# <!-- end WebMoney Transfer : attestation label -->
# <!--img src="/template/be1/images/acc_white_on_transp_ru.png" alt="wm_atestat" class="pay">
# 				<img src="/template/be1/images/v_blue_on_white_ru.png" alt="wm_atestat" class="pay"-->
# </div>
# <div class="col-sm-12 col-md-10">
# <div class="row">
# <div class="col-sm-3 col-md-3 margin_bottom40">
# <div class="heading">Внутренняя оптимизация</div>
# <a href="/stat/">Анализ сайта</a><br/>
# <a href="/audit/">Аудит сайта</a><br/>
# <a href="/antiplagiat-online/">Антиплагиат онлайн</a><br/>
# <a href="/rasshireniye-semanticheskogo-yadra/">Расширение семантического ядра</a><br/>
# <a href="/grupirovka-zaprosov/">Группировка поисковых запросов</a><br/>
# <a href="/vfacen/">Оценка тошноты страницы</a><br/>
# <a href="/otvet-servera/">Проверка заголовков сервера</a><br/>
# <a href="/site-speed/">Анализ скорости сайта</a><br/>
# <a href="/morphology-analysis/">Морфологический разбор слова</a><br/>
# </div>
# <div class="col-sm-3 col-md-3 margin_bottom40">
# <div class="heading">Фильтры / Санкции</div>
# <a href="/affiliation/">Аффилированность сайтов</a><br/>
# <a href="/proverka-na-perespam/">Проверка на фильтр переспам</a><br/>
# <a href="/proverka-virus/">Проверка сайтов на вирусы</a><br/>
# </div>
# <div class="col-sm-3 col-md-3 margin_bottom40">
# <div class="heading">Аналитические</div>
# <a href="/wordstat/">Проверка частотности запросов</a><br/>
# <a href="/position-yandex-google/">Проверка позиций сайта</a><br/>
# <a href="/vozrast-stranicy/">Определить возраст страницы</a><br/>
# <a href="/regionalnost-sayta/">Определение региональности сайта</a><br/>
# <a href="/site-cost/">Оценка стоимости сайта</a><br/>
# <a href="/uznat-poddomeni-saita/">Узнать поддомены сайта</a><br/>
# <a href="/yandex-iks/">Яндекс ИКС</a><br/>
# <a href="/proverit-skleyku-domenov/">Проверить склейку доменов</a><br/>
# <a href="/proverka-whois/">WHOIS</a><br/>
# <a href="/cms/">Определить CMS</a><br/>
# </div>
# <div class="col-sm-3 col-md-3 margin_bottom40">
# <div class="heading">Пользовательские</div>
# <a href="/speed-test-internet/">Проверка скорости интернет</a><br/>
# <a href="/password-generator/">Генератор паролей онлайн</a><br/>
# <a href="/podschet-kolichestva-simvolov/">Подсчет количества символов</a><br/>
# <a href="/transliteratsiya/">Транслитерация онлайн</a><br/>
# <a href="/html-redaktor-online/">Визуальный HTML редактор онлайн</a><br/>
# <a href="/generator-favicon/">Favicon.ico генератор</a><br/>
# <a href="/my-ip/">Мой IP</a><br/>
# <a href="/sintaksicheskij-razbor-predlozheniya/">Синтаксический разбор предложения</a><br/>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-6 extensions">
# <a class="extension_btn cursor_hand" href="
# 						 https://chrome.google.com/webstore/detail/seo-анализ-сайта-от-be1ru/hgoppfmeamohhpdlgmbondkfcijhklbo						 				 " target="_blank">
# <div class="browser unknown">
# <div class="caption">Установить расширение</div>
# </div>
# </a>
# </div>
# <div class="col-md-6 social">
# <a class="vk" href="https://vk.com/be1_ru" target="_blank"></a>
# <a class="facebook" href="https://www.facebook.com/be1.ru/" target="_blank"></a>
# <a class="twitter" href="https://twitter.com/Be1_ru" target="_blank"></a>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="container">
# <div class="row">
# <div class="col-md-4">
# 					© 2001-2023. Все права защищены.
# 				</div>
# <div class="col-md-4">
# <a href="mailto:info@be1.ru"><i class="fa fa-envelope margin_right10"></i>info@be1.ru</a>
# </div>
# <div class="col-md-4">
# <a class="ad" href="/advertising/"><i class="fa fa-bullhorn"></i>Реклама на сайте</a>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script src="/template/be1/vendor/jquery-ui/1.12.1.custom/jquery-ui.min.js"></script>
# <script src="/template/be1/vendor/bootstrap-3.3.7/js/bootstrap.min.js"></script>
# <script src="/template/be1/js/common.js?v=89"></script>
# <script src="https://be1.ru/template/be1/vendor/silviomoreto-bootstrap-select/js/bootstrap-select.min.js"></script>
# <script src="https://be1.ru/template/be1/vendor/silviomoreto-bootstrap-select/js/defaults-ru_RU.min.js"></script>
# <script src="https://be1.ru/template/be1/vendor/FileSaver/FileSaver.min.js"></script>
# <script src="https://be1.ru/template/be1/js/tools/analiz_saita_view.js?v=25"></script>
# <script src="https://be1.ru/template/be1/js/tools/analiz_saita_view_yandex_webmaster.js?v=1"></script>
# <script src="https://be1.ru/template/be1/js/tools/analiz_saita_view_analiz_konkurentov.js"></script>
# <script src="https://be1.ru/template/be1/js/tools/analiz_saita_view_bonus.js"></script>
# <script src="https://be1.ru/template/be1/js/banners.js?v=2"></script>
# <script src="//www.google.com/recaptcha/api.js?render=6LcaV7kUAAAAAFtP5X0YWuWcZRooXX_PWJc_pi53"></script>
# <script>
# 	grecaptcha.ready(function() {
# 		grecaptcha.execute('6LcaV7kUAAAAAFtP5X0YWuWcZRooXX_PWJc_pi53', {action: 'examples/v3scores'}).then(function(token) {
#             $.ajax({
#                 url:'/recaptchav3/check',
#                 type:'POST',
#                 data:'token='+token,
#                 success:function(data){
#
#                 }
#             });
# 		});
# 	});
# </script>
# <!-- Stat.MegaIndex.ru Start  -->
# <script>
# var mi=document.createElement('script');mi.type='text/javascript';mi.async=true;mi.src=(document.location.protocol=='https:'?'https':'http')+'://counter.megaindex.ru/core.js?t;'+escape(document.referrer)+((typeof(screen)=='undefined')?'':';'+screen.width+'*'+screen.height)+';'+escape(document.URL)+';'+document.title.substring(0,256)+';6';document.getElementsByTagName('head')[0].appendChild(mi);
# </script>
# <!-- Stat.MegaIndex.ru End -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-90723352-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-90723352-1');
# </script>
# </body>
# </html>

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
data_table = []
table = soup.find('table', attrs={'class':'table main'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data_table.append([ele for ele in cols if ele]) # Get rid of empty values

for i in range(len(data_table)):
    data_1 = [data_table[i][1], LINK + data_table[i][3], data_table[i][4]]
    data_table[i] = data_1

# %%
data_table
# Out:
# [['мисис', 'https://misis.ru/', '2380'],
#  ['миссис', 'https://misis.ru/', '1600'],
#  ['горный',
#   'https://misis.ru/university/struktura-universiteta/instituty/gi/',
#   '1971'],
#  ['горный университет',
#   'https://misis.ru/university/struktura-universiteta/instituty/gi/',
#   '1175'],
#  ['ниту мисис', 'https://misis.ru/', '559'],
#  ['мисис официальный сайт', 'https://misis.ru/', '247'],
#  ['ниту мисис официальный сайт', 'https://misis.ru/', '234'],
#  ['горный институт',
#   'https://misis.ru/university/struktura-universiteta/instituty/gi/',
#   '233'],
#  ['бизнес информатика',
#   'https://misis.ru/applicants/admission/baccalaureate-and-specialty/faculties/bi/',
#   '381'],
#  ['национальный исследовательский технологический университет мисис',
#   'https://misis.ru/',
#   '187']]

# %%
df = pd.DataFrame(data_table)
df
# Out:
#                                                    0  \
# 0                                              мисис
# 1                                             миссис
# 2                                             горный
# 3                                 горный университет
# 4                                         ниту мисис
# 5                             мисис официальный сайт
# 6                        ниту мисис официальный сайт
# 7                                    горный институт
# 8                                 бизнес информатика
# 9  национальный исследовательский технологический...
#
#                                                    1     2
# 0                               https://profbuh8.ru/  2380
# 1                               https://profbuh8.ru/  1600
# 2  https://profbuh8.ru/university/struktura-unive...  1971
# 3  https://profbuh8.ru/university/struktura-unive...  1175
# 4                               https://profbuh8.ru/   559
# 5                               https://profbuh8.ru/   247
# 6                               https://profbuh8.ru/   234
# 7  https://profbuh8.ru/university/struktura-unive...   233
# 8  https://profbuh8.ru/applicants/admission/bacca...   381
# 9                               https://profbuh8.ru/   187

# %%
def clear_str(my_str):
    return my_str.replace('\n', '').replace('\t', '').replace('\r', '')

# %%
import re
import ast

matches = re.findall(r'google\.visualization\.arrayToDataTable\((.*?)\)', clear_str(str(soup)))
dict_list = []
for i, match in enumerate(matches):
    if match != 'data':
        try:
            print(f"Data {i+1}: {match}")
            match = match.replace("//", "")
            match = re.sub(r'/\*.*?\*/', '', match)
            list_data = ast.literal_eval(match)
            dict_data = {item[0]: item[1:] for item in list_data}
            dict_list.append(dict_data)
            print(dict_data)
        except:
            domain_names = re.findall(r'"([\w.-]+\.[\w.-]+)"', match)
            print(domain_names)
# Out:
# Data 1: [            ['Year', 'Количество запросов', 'Количество эффективных показов'],            ['Август',  298, 11256],['Сентябрь',  224, 11027],['Октябрь',  231, 11397],['Ноябрь',  282, 10524],['Декабрь',  274, 10685],['Январь',  211, 8427],['Февраль',  287, 12327],['Март',  304, 10272],['Апрель',  27, 8059],['Май',  31, 7814],['Июнь',  12, 196],['Июль',  230, 806],        ]
# {'Year': ['Количество запросов', 'Количество эффективных показов'], 'Август': [298, 11256], 'Сентябрь': [224, 11027], 'Октябрь': [231, 11397], 'Ноябрь': [282, 10524], 'Декабрь': [274, 10685], 'Январь': [211, 8427], 'Февраль': [287, 12327], 'Март': [304, 10272], 'Апрель': [27, 8059], 'Май': [31, 7814], 'Июнь': [12, 196], 'Июль': [230, 806]}
# Data 4: [            ['Year', 'Кол. ссылающихся доменов'],['Октябрь', 2703],['Ноябрь', 2702],['Декабрь', 2547],['Январь', 2479],['Февраль', 2446],['Март', 2424],['Апрель', 2384],['Май', 2392],['Июнь', 2349],['Июль', 2280],['Август', 2222],['Сентябрь', 2183],        ]
# {'Year': ['Кол. ссылающихся доменов'], 'Октябрь': [2703], 'Ноябрь': [2702], 'Декабрь': [2547], 'Январь': [2479], 'Февраль': [2446], 'Март': [2424], 'Апрель': [2384], 'Май': [2392], 'Июнь': [2349], 'Июль': [2280], 'Август': [2222], 'Сентябрь': [2183]}
# Data 5: [            ['Year', 'Кол. уникальных ссылок'],            ['Сентябрь', 585],['Октябрь', 585],['Ноябрь', 585],['Декабрь', 644],['Январь', 644],['Февраль', 644],['Март', 604],['Апрель', 824],['Май', 824],['Июнь', 824],['Июль', 7],        ]
# {'Year': ['Кол. уникальных ссылок'], 'Сентябрь': [585], 'Октябрь': [585], 'Ноябрь': [585], 'Декабрь': [644], 'Январь': [644], 'Февраль': [644], 'Март': [604], 'Апрель': [824], 'Май': [824], 'Июнь': [824], 'Июль': [7]}
# Data 6: [['Year', 'Количество заходов'],['Июнь',  582958],['Июль',  486935],['Авг',  352382],]
# {'Year': ['Количество заходов'], 'Июнь': [582958], 'Июль': [486935], 'Авг': [352382]}
# Data 7: [['Task', 'Hours per Day'],['Директ',   0.37818610462445],['Реферальные ссылки', 0.044701396605014],['Поиск',  0.40355520312018],['Социальные сети', 0.085010976503368],['Почтовая рассылка', 0.088546319146989],//['Дисплей', ],]
# {'Task': ['Hours per Day'], 'Директ': [0.37818610462445], 'Реферальные ссылки': [0.044701396605014], 'Поиск': [0.40355520312018], 'Социальные сети': [0.085010976503368], 'Почтовая рассылка': [0.088546319146989], 'Дисплей': []}
# Data 8: [['Country', 'Посещаемость, %'],['Russia', 91.08],['France', 1.63],['Uzbekistan', 0.98],['Japan', 0.64],['Georgia', 0.62],/*['Germany', 200],['United States', 300],['Brazil', 400],['Canada', 500],['France', 600],['RU', 700]*/]
# {'Country': ['Посещаемость, %'], 'Russia': [91.08], 'France': [1.63], 'Uzbekistan': [0.98], 'Japan': [0.64], 'Georgia': [0.62]}
# Data 9: [            ["Element", "Рейтинг", {type: 'string', role: 'annotation'}, { role: "style" } ],            ["msph.ru",0.20618255, 0.20618255, "#7FD4D8"],["abit.etu.ru",0.19753154, 0.19753154, "#7FD4D8"],["kopernikfitness.ru",0.17032924, 0.17032924, "#7FD4D8"],["sf.misis.ru",0.15222399, 0.15222399, "#7FD4D8"],["hse.ru",0.14747054, 0.14747054, "#7FD4D8"],["ucheba.ru",0.13897846, 0.13897846, "#7FD4D8"],["ranepa.ru",0.13614951, 0.13614951, "#7FD4D8"],["vuzopedia.ru",0.12579951, 0.12579951, "#7FD4D8"],["mirea.ru",0.12198354, 0.12198354, "#7FD4D8"],["miit.ru",0.11701906, 0.11701906, "#7FD4D8"],        ]
# ['msph.ru', 'abit.etu.ru', 'kopernikfitness.ru', 'sf.misis.ru', 'hse.ru', 'ucheba.ru', 'ranepa.ru', 'vuzopedia.ru', 'mirea.ru', 'miit.ru']

# %%
data = {
    'title': soup.find(id="set_title").text,
    'description': soup.find(id="set_description").text,
    'vozrast': soup.find(id="set_vozrast").text,
    'page_size': soup.find(id="set_page_size").text,
    'page_load_time': soup.find(id="set_page_load_time").text,
    'ip': soup.find(id="set_site_ip").text,
    'yandex_iks': soup.find(id="set_iks").text.replace('\n', ''),
    'competitiors': domain_names,
    'yandex_request': data_table,
}

# %%
dict_list
# Out:
# [{'Year': ['Количество запросов', 'Количество эффективных показов'],
#   'Август': [298, 11256],
#   'Сентябрь': [224, 11027],
#   'Октябрь': [231, 11397],
#   'Ноябрь': [282, 10524],
#   'Декабрь': [274, 10685],
#   'Январь': [211, 8427],
#   'Февраль': [287, 12327],
#   'Март': [304, 10272],
#   'Апрель': [27, 8059],
#   'Май': [31, 7814],
#   'Июнь': [12, 196],
#   'Июль': [230, 806]},
#  {'Year': ['Кол. ссылающихся доменов'],
#   'Октябрь': [2703],
#   'Ноябрь': [2702],
#   'Декабрь': [2547],
#   'Январь': [2479],
#   'Февраль': [2446],
#   'Март': [2424],
#   'Апрель': [2384],
#   'Май': [2392],
#   'Июнь': [2349],
#   'Июль': [2280],
#   'Август': [2222],
#   'Сентябрь': [2183]},
#  {'Year': ['Кол. уникальных ссылок'],
#   'Сентябрь': [585],
#   'Октябрь': [585],
#   'Ноябрь': [585],
#   'Декабрь': [644],
#   'Январь': [644],
#   'Февраль': [644],
#   'Март': [604],
#   'Апрель': [824],
#   'Май': [824],
#   'Июнь': [824],
#   'Июль': [7]},
#  {'Year': ['Количество заходов'],
#   'Июнь': [582958],
#   'Июль': [486935],
#   'Авг': [352382]},
#  {'Task': ['Hours per Day'],
#   'Директ': [0.37818610462445],
#   'Реферальные ссылки': [0.044701396605014],
#   'Поиск': [0.40355520312018],
#   'Социальные сети': [0.085010976503368],
#   'Почтовая рассылка': [0.088546319146989],
#   'Дисплей': []},
#  {'Country': ['Посещаемость, %'],
#   'Russia': [91.08],
#   'France': [1.63],
#   'Uzbekistan': [0.98],
#   'Japan': [0.64],
#   'Georgia': [0.62]}]

# %%
for el in dict_list:
    if 'Year' in el:
            if el['Year'][0] == 'Количество запросов':
                el['Title'] = el.pop('Year')
                data['requests'] = el
            elif el['Year'][0] == 'Количество заходов':
                el['Title'] = el.pop('Year')
                data['visits_by_month'] = el
    elif 'Country' in el:
        el['Title'] = el.pop('Country')
        data['visits_by_country'] = el

# %%
data
# Out:
# {'title': 'Университет науки и\xa0технологий МИСИС\xa0— официальный сайт',
#  'description': 'Университет науки и технологий МИСИС в Москве: информация для поступающих, новости, институты, программы подготовки',
#  'vozrast': '23 года 364 дня',
#  'page_size': '50.38 КБ',
#  'page_load_time': '2100 сек',
#  'ip': '5.253.61.53',
#  'yandex_iks': '6600',
#  'competitiors': ['msph.ru',
#   'abit.etu.ru',
#   'kopernikfitness.ru',
#   'sf.misis.ru',
#   'hse.ru',
#   'ucheba.ru',
#   'ranepa.ru',
#   'vuzopedia.ru',
#   'mirea.ru',
#   'miit.ru'],
#  'yandex_request': [['мисис', 'https://profbuh8.ru/', '2380'],
#   ['миссис', 'https://profbuh8.ru/', '1600'],
#   ['горный',
#    'https://profbuh8.ru/university/struktura-universiteta/instituty/gi/',
#    '1971'],
#   ['горный университет',
#    'https://profbuh8.ru/university/struktura-universiteta/instituty/gi/',
#    '1175'],
#   ['ниту мисис', 'https://profbuh8.ru/', '559'],
#   ['мисис официальный сайт', 'https://profbuh8.ru/', '247'],
#   ['ниту мисис официальный сайт', 'https://profbuh8.ru/', '234'],
#   ['горный институт',
#    'https://profbuh8.ru/university/struktura-universiteta/instituty/gi/',
#    '233'],
#   ['бизнес информатика',
#    'https://profbuh8.ru/applicants/admission/baccalaureate-and-specialty/faculties/bi/',
#    '381'],
#   ['национальный исследовательский технологический университет мисис',
#    'https://profbuh8.ru/',
#    '187']],
#  'requests': {'Август': [298, 11256],
#   'Сентябрь': [224, 11027],
#   'Октябрь': [231, 11397],
#   'Ноябрь': [282, 10524],
#   'Декабрь': [274, 10685],
#   'Январь': [211, 8427],
#   'Февраль': [287, 12327],
#   'Март': [304, 10272],
#   'Апрель': [27, 8059],
#   'Май': [31, 7814],
#   'Июнь': [12, 196],
#   'Июль': [230, 806],
#   'Title': ['Количество запросов', 'Количество эффективных показов']},
#  'visits_by_month': {'Июнь': [582958],
#   'Июль': [486935],
#   'Авг': [352382],
#   'Title': ['Количество заходов']},
#  'visits_by_country': {'Russia': [91.08],
#   'France': [1.63],
#   'Uzbekistan': [0.98],
#   'Japan': [0.64],
#   'Georgia': [0.62],
#   'Title': ['Посещаемость, %']}}

# %%
with open('data.txt', 'w') as f:
    for key, value in data.items():
        f.write(f'{key}: {value}\n')

# %%
import json

with open('data.json', 'w') as f:
    json.dump(data, f)

# %%
pip install pyppeteer
# Out:
# Collecting pyppeteer
#   Using cached pyppeteer-1.0.2-py3-none-any.whl (83 kB)
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting certifi>=2021 (from pyppeteer)
#   Obtaining dependency information for certifi>=2021 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting importlib-metadata>=1.4 (from pyppeteer)
#   Obtaining dependency information for importlib-metadata>=1.4 from https://files.pythonhosted.org/packages/cc/37/db7ba97e676af155f5fcb1a35466f446eadc9104e25b83366e8088c9c926/importlib_metadata-6.8.0-py3-none-any.whl.metadata
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer)
#   Using cached pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Collecting tqdm<5.0.0,>=4.42.1 (from pyppeteer)
#   Obtaining dependency information for tqdm<5.0.0,>=4.42.1 from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer)
#   Obtaining dependency information for urllib3<2.0.0,>=1.25.8 from https://files.pythonhosted.org/packages/c5/05/c214b32d21c0b465506f95c4f28ccbcba15022e000b043b72b3df7728471/urllib3-1.26.16-py2.py3-none-any.whl.metadata
#   Using cached urllib3-1.26.16-py2.py3-none-any.whl.metadata (48 kB)
# Collecting websockets<11.0,>=10.0 (from pyppeteer)
#   Using cached websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=1.4->pyppeteer)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/d9/66/48866fc6b158c81cc2bfecc04c480f105c6040e8b077bc54c634b4a67926/zipp-3.17.0-py3-none-any.whl.metadata
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: pyee, appdirs, zipp, websockets, urllib3, tqdm, certifi, importlib-metadata, pyppeteer
# Successfully installed appdirs-1.4.4 certifi-2023.7.22 importlib-metadata-6.8.0 pyee-8.2.2 pyppeteer-1.0.2 tqdm-4.66.1 urllib3-1.26.16 websockets-10.4 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.
